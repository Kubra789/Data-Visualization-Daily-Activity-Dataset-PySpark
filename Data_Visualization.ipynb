# %%
# Daily Activity Dataset/ Data Visualization With PySpark

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
spark= SparkSession.builder.appName("Data Visualization Çalışması").getOrCreate()

# %%
df=spark.read.option("delimiter",",").option("header","true").option("inferSchema","true").csv("/FileStore/tables/DailyActivities.csv")

# %%
df.show(truncate=False)
# Out:
# +----------------+-------+-----+-----+
# |Area of Interest|Charles|Henry|Susan|
# +----------------+-------+-----+-----+
# |Work            |8.5    |9.5  |7.0  |
# |Family          |0.5    |1.0  |1.5  |
# |Homeworks       |3.0    |2.0  |1.0  |
# |Individual      |1.0    |1.5  |2.5  |
# |Socializing     |1.5    |0.5  |2.0  |
# |Spare Time      |3.0    |2.5  |2.0  |
# |Sleep           |6.5    |7.0  |8.0  |
# +----------------+-------+-----+-----+

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Area of Interest</th><th>Charles</th><th>Henry</th><th>Susan</th></tr></thead><tbody><tr><td>Work</td><td>8.5</td><td>9.5</td><td>7.0</td></tr><tr><td>Family</td><td>0.5</td><td>1.0</td><td>1.5</td></tr><tr><td>Homeworks</td><td>3.0</td><td>2.0</td><td>1.0</td></tr><tr><td>Individual</td><td>1.0</td><td>1.5</td><td>2.5</td></tr><tr><td>Socializing</td><td>1.5</td><td>0.5</td><td>2.0</td></tr><tr><td>Spare Time</td><td>3.0</td><td>2.5</td><td>2.0</td></tr><tr><td>Sleep</td><td>6.5</td><td>7.0</td><td>8.0</td></tr></tbody></table></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Area of Interest</th><th>Charles</th><th>Henry</th><th>Susan</th></tr></thead><tbody><tr><td>Work</td><td>8.5</td><td>9.5</td><td>7.0</td></tr><tr><td>Family</td><td>0.5</td><td>1.0</td><td>1.5</td></tr><tr><td>Homeworks</td><td>3.0</td><td>2.0</td><td>1.0</td></tr><tr><td>Individual</td><td>1.0</td><td>1.5</td><td>2.5</td></tr><tr><td>Socializing</td><td>1.5</td><td>0.5</td><td>2.0</td></tr><tr><td>Spare Time</td><td>3.0</td><td>2.5</td><td>2.0</td></tr><tr><td>Sleep</td><td>6.5</td><td>7.0</td><td>8.0</td></tr></tbody></table></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Area of Interest</th><th>Charles</th><th>Henry</th><th>Susan</th></tr></thead><tbody><tr><td>Work</td><td>8.5</td><td>9.5</td><td>7.0</td></tr><tr><td>Family</td><td>0.5</td><td>1.0</td><td>1.5</td></tr><tr><td>Homeworks</td><td>3.0</td><td>2.0</td><td>1.0</td></tr><tr><td>Individual</td><td>1.0</td><td>1.5</td><td>2.5</td></tr><tr><td>Socializing</td><td>1.5</td><td>0.5</td><td>2.0</td></tr><tr><td>Spare Time</td><td>3.0</td><td>2.5</td><td>2.0</td></tr><tr><td>Sleep</td><td>6.5</td><td>7.0</td><td>8.0</td></tr></tbody></table></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Area of Interest</th><th>Charles</th><th>Henry</th><th>Susan</th></tr></thead><tbody><tr><td>Work</td><td>8.5</td><td>9.5</td><td>7.0</td></tr><tr><td>Family</td><td>0.5</td><td>1.0</td><td>1.5</td></tr><tr><td>Homeworks</td><td>3.0</td><td>2.0</td><td>1.0</td></tr><tr><td>Individual</td><td>1.0</td><td>1.5</td><td>2.5</td></tr><tr><td>Socializing</td><td>1.5</td><td>0.5</td><td>2.0</td></tr><tr><td>Spare Time</td><td>3.0</td><td>2.5</td><td>2.0</td></tr><tr><td>Sleep</td><td>6.5</td><td>7.0</td><td>8.0</td></tr></tbody></table></div>

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Area of Interest</th><th>Charles</th><th>Henry</th><th>Susan</th></tr></thead><tbody><tr><td>Work</td><td>8.5</td><td>9.5</td><td>7.0</td></tr><tr><td>Family</td><td>0.5</td><td>1.0</td><td>1.5</td></tr><tr><td>Homeworks</td><td>3.0</td><td>2.0</td><td>1.0</td></tr><tr><td>Individual</td><td>1.0</td><td>1.5</td><td>2.5</td></tr><tr><td>Socializing</td><td>1.5</td><td>0.5</td><td>2.0</td></tr><tr><td>Spare Time</td><td>3.0</td><td>2.5</td><td>2.0</td></tr><tr><td>Sleep</td><td>6.5</td><td>7.0</td><td>8.0</td></tr></tbody></table></div>
